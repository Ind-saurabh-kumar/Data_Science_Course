# %% [markdown]
# # Linear Algebra in Python

# %%
import numpy as np

# %%
# coefficeient matrix A 

A = np.array([[2,3], [5,7]])     # 2x2 matrix

A
# Out:
# array([[2, 3],
#        [5, 7]])

# %%
# constant matrix B 

B = np.array([8,20])
B
# Out:
# array([ 8, 20])

# %% [markdown]
# 2x + 3y = 8
#
# 5x + 4y = 20

# %%
# solve for x 

X = np.linalg.solve(A,B) 

X
# Out:
# array([4., 0.])

# %% [markdown]
# # Solving Complex Equations

# %% [markdown]
# ### letax language
#
#
# \[
# \begin{align*}
# (1+2i)x +( 2-i)y &=4+i \\
# (3-i)x + 4y &= 3 +4i
# \end{align*}
# \]

# %%
# Coefficients matrix A with complex numbers

A_complex = np.array([[1+2j, 2-1j], [3-1j, 4]])

A_complex
# Out:
# array([[1.+2.j, 2.-1.j],
#        [3.-1.j, 4.+0.j]])

# %%
# Constants matrix B with complex numbers

B_complex = np.array([4+1j, 3+4j])
B_complex
# Out:
# array([4.+1.j, 3.+4.j])

# %%
# solving for X in the complex case 

X_complex = np.linalg.solve(A_complex, B_complex)
X_complex
# Out:
# array([-0.11176471-0.45294118j,  0.94705882+1.31176471j])

# %% [markdown]
# # vectors in Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# create a vector

v = np.array([2,3])
v
# Out:
# array([2, 3])

# %%
# plot the vector v

plt.figure()

plt.quiver(0,0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r')

plt.xlim(-1,5)

plt.ylim(-1,5)

plt.grid()

plt.title('2D Vector')

plt.xlabel('X axis')

plt.ylabel('Y axis')

plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# ---
# # Linear Transform

# %% [markdown]
# \[
# \begin{bmatrix}
# \cos(45^\circ) & -\sin(45^\circ) \\
# \sin(45^\circ) & \cos(45^\circ)
# \end{bmatrix}
# \]

# %%
ve = np.array([3,3])
ve
# Out:
# array([3, 3])

# %%
# Define the rotation matrix for 45 degree rotation

theta = np.radians(55)

rotation_matrix = np.array ([[np.cos(theta), -np.sin(theta)],
                            [np.sin(theta), np.cos(theta)]])


print(rotation_matrix)

print("--------------------------------------")

print(ve)


# Applying the transformation 

v_transforemd = np.dot(rotation_matrix, ve)

v_transforemd
# Out:
# [[ 0.57357644 -0.81915204]
#  [ 0.81915204  0.57357644]]
# --------------------------------------
# [3 3]
# array([-0.73672682,  4.17818544])

# %%
# Plotting the original and transformed vectors 

plt.figure()

plt.quiver(0,0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')

plt.quiver(0,0, v_transforemd[0], v_transforemd[1], angles='xy', scale_units='xy', label='Transformed Vector', scale=1, color='blue')


plt.xlim(-1,5)
plt.ylim(-1,5)

plt.grid()

plt.title('2D Vector Transformeation')

plt.xlabel('X axis')

plt.ylabel('Y axis')

plt.legend()

plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
# Plotting the original and transformed vectors 

plt.figure()

plt.quiver(0,0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')

plt.quiver(0,0, v_transforemd[0], v_transforemd[1], angles='xy', scale_units='xy', label='Transformed Vector', scale=1, color='blue')


plt.xlim(-5,5)
plt.ylim(-5,5)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)

plt.title('2D Vector Transformeation')

plt.xlabel('X axis')

plt.ylabel('Y axis')

plt.legend()

plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# ---
# # Shear Transformation

# %%
shear_factor = 1.5
shear_matrix = np.array([[1, shear_factor], [0,  1]])
v_sheared = np.dot(shear_matrix, v)


# Plotting the original , rotated, and sheared vectors

plt.figure()

plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')

plt.quiver(0, 0, v_transforemd[0], v_transforemd[1], angles='xy', scale_units='xy', scale=1, color='g', label='Rotated vector')

plt.quiver(0, 0, v_sheared[0], v_sheared[1], angles='xy', scale_units='xy', scale=1, color='y', label='Shear Vector')

plt.xlim(-5, 10)

plt.ylim(-5,10)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.axhline(y=0, color='k', linewidth=0.5)

plt.axvline(x=0, color='k', linewidth=0.5)

plt.title('2D Vector Transformations')

plt.xlabel('X axis')

plt.ylabel('Y axis')

plt.legend()

plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
# adjusting the plot to include the effect fo sharing on the grid lines

# Creating a grid of pints 

x = np.linspace(-5, 10, 10)

y = np.linspace (-5, 10, 10)

X, Y= np.meshgrid(x,y)

# Applying sear transformation to the grid points

X_sheared, Y_sheared = np.dot(shear_matrix, [X.ravel(), Y.ravel()])

X_sheared = X_sheared.reshape(X.shape)
Y_sheared = Y_sheared.reshape(Y.shape)

# pLOTTING THE SHEARD GRID LINES 


plt.figure()

plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r', label='Original Vector')

plt.quiver(0,0, v_transforemd[0], v_transforemd[1], angles ='xy', scale_units='xy', scale=1, color='g', label='Rotation Vector')

plt.quiver(0,0, v_sheared[0], v_sheared[1], angles='xy', scale_units='xy', scale=1, color='y', label='Sheared Vector')



for i in range(len(x)):
    plt.plot(X_sheared[i, :], Y_sheared[i, :], 'k--', linewidth=0.5)
    plt.plot(X_sheared[:, i], Y_sheared[:, i], 'k--', linewidth=0.5)



plt.xlim(-5, 10)
plt.ylim(-5, 10)

plt.title('2D Vector Transformations with sheared Grid')

plt.xlabel('X axis')

plt.ylabel('Y axis')

plt.legend()

plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# ---
#
# # SVD in python

# %%
# generate a matrix of 4x3 dataset

A = np.random.rand(4,3)
A
# Out:
# array([[0.30152012, 0.94932403, 0.77780484],
#        [0.33719113, 0.60903952, 0.07305883],
#        [0.91893739, 0.87160062, 0.11313855],
#        [0.17286641, 0.00874879, 0.06498466]])

# %%
# letSa apply SVD here
U, Sigma, VT =np.linalg.svd(A)


print("U Matrix =", U)
print("-----------------------------------")
print ("Sigma Matrix= ", Sigma)
print("--------------------------------------")
print ("V^T Matrix=" , VT)
# Out:
# U Matrix = [[-0.64338453  0.75225911 -0.12432826 -0.06859338]
#  [-0.37506887 -0.1502996   0.72086803  0.56310093]
#  [-0.66412685 -0.63461047 -0.22293401 -0.32635181]
#  [-0.0656903  -0.09373261 -0.64435409  0.75611295]]
# -----------------------------------
# Sigma Matrix=  [1.80799555 0.65581248 0.19812571]
# --------------------------------------
# V^T Matrix= [[-0.52107978 -0.78464809 -0.33586195]
#  [-0.64535056  0.10468287  0.75667969]
#  [-0.55856828  0.61103918 -0.5609212 ]]

# %%
U.shape
# Out:
# (4, 4)

# %%
Sigma.shape
# Out:
# (3,)

# %%
VT.shape
# Out:
# (3, 3)
